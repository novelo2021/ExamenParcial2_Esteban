# %% [markdown]
# ## Aquí se muestran los primeros 10 artistas ordenados alfabeticamente

# %%
import pandas as pd
df = pd.read_csv("data.csv")
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import numpy as np 
import seaborn as sns 
from matplotlib import pyplot as plt 
# %matplotlib inline

# %% [markdown]
# ## Aquí se muestran los primeros 10 artistas ordenados alfabeticamente

# %%
df = df.head(10).sort_values(by='artists', ascending=True)

# %%
df['artists']
# Out:
# 1            ["Screamin' Jay Hawkins"]
# 8                 ['Francisco Canaro']
# 5    ['Mamie Smith & Her Jazz Hounds']
# 7    ['Mamie Smith & Her Jazz Hounds']
# 0                      ['Mamie Smith']
# 2                      ['Mamie Smith']
# 6                      ['Mamie Smith']
# 9                           ['Meetya']
# 4                             ['Mixe']
# 3                  ['Oscar Velazquez']
# Name: artists, dtype: object

# %% [markdown]
# ## Aquí los posibles datos que se pueden relacionar entre sí

# %%
df
# Out:
#    acousticness                            artists  danceability  duration_ms  \
# 1      0.643000          ["Screamin' Jay Hawkins"]         0.852       150200
# 8      0.996000               ['Francisco Canaro']         0.469       146840
# 5      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.424       198627
# 7      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.474       186173
# 0      0.991000                    ['Mamie Smith']         0.598       168333
# 2      0.993000                    ['Mamie Smith']         0.647       163827
# 6      0.992000                    ['Mamie Smith']         0.782       195200
# 9      0.006820                         ['Meetya']         0.571       476304
# 4      0.295000                           ['Mixe']         0.704       165224
# 3      0.000173                ['Oscar Velazquez']         0.730       422087
#
#    energy  explicit                      id  instrumentalness  key  liveness  \
# ...

# %%
relacion = df[['artists','danceability','duration_ms','energy']]

# %%
relacion.head(10)
# Out:
#                              artists  danceability  duration_ms  energy
# 1          ["Screamin' Jay Hawkins"]         0.852       150200  0.5170
# 8               ['Francisco Canaro']         0.469       146840  0.2380
# 5  ['Mamie Smith & Her Jazz Hounds']         0.424       198627  0.2450
# 7  ['Mamie Smith & Her Jazz Hounds']         0.474       186173  0.2390
# 0                    ['Mamie Smith']         0.598       168333  0.2240
# 2                    ['Mamie Smith']         0.647       163827  0.1860
# 6                    ['Mamie Smith']         0.782       195200  0.0573
# 9                         ['Meetya']         0.571       476304  0.7530
# 4                           ['Mixe']         0.704       165224  0.7070
# 3                ['Oscar Velazquez']         0.730       422087  0.7980

# %% [markdown]
# ## Sacar: Media, promedio, valor máximo, valor mínimo

# %%
relacion.describe()
# Out:
#        danceability   duration_ms     energy
# count     10.000000      10.00000  10.000000
# mean       0.625100  227281.50000   0.396430
# std        0.143415  118914.78051   0.271053
# min        0.424000  146840.00000   0.057300
# 25%        0.498250  164176.25000   0.227500
# 50%        0.622500  177253.00000   0.242000
# 75%        0.723500  197770.25000   0.659500
# max        0.852000  476304.00000   0.798000

# %%
df.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  115696.000000  115696.000000  1.156960e+05  115696.000000
# mean        0.525709       0.537079  2.284875e+05       0.465463
# std         0.380974       0.174326  1.512579e+05       0.272076
# min         0.000000       0.000000  5.108000e+03       0.000000
# 25%         0.110000       0.416000  1.636000e+05       0.232000
# 50%         0.577000       0.549000  2.014930e+05       0.437000
# 75%         0.920000       0.669000  2.600270e+05       0.691000
# max         0.996000       0.988000  5.338302e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  115696.000000     115696.000000  115696.000000  115696.000000
# mean        0.069302          0.196801       5.198062       0.209169
# std         0.253969          0.334850       3.510434       0.174877
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %% [markdown]
# #### Varianza

# %%
var = df.var()

# %%
print(var)
# Out:
# acousticness        1.451415e-01
# danceability        3.038949e-02
# duration_ms         2.287896e+10
# energy              7.402541e-02
# explicit            6.450006e-02
# instrumentalness    1.121245e-01
# key                 1.232315e+01
# liveness            3.058191e-02
# loudness            3.261925e+01
# mode                2.077343e-01
# popularity          5.342024e+02
# speechiness         3.832578e-02
# tempo               9.225148e+02
# valence             6.899835e-02
# year                7.731273e+02
# dtype: float64

# %% [markdown]
# ## ¿Cuales valores pueden tener una relación lineal positiva, demuestre y diga el porqué lo considera así?

# %%
sns.pairplot(relacion, kind ='reg')

# %% [markdown]
# ### Respuesta: Los valores que parecen estar relacionados de manera positiva son ´danceability´, ´duration_ms´ y ´energry´ porque van de forma ascendente y son dependientes entre sí
